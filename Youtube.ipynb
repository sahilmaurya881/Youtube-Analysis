# %% [markdown]
# # COMPLETE DATA ANALYSIS ON YOUTUBE DATASET

# %% [markdown]
# # IMPORTING MODULES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import cm
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %% [markdown]
# # LOADING THE DATASET

# %%
Youtube_df = pd.read_csv('/content/youtube.csv')

# %%
Youtube_df
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# # VIEWING DATA TO UNDERSTAND THE VARIABLES AND LABELS

# %%
Youtube_df.head()
# Out:
#    index     video_id trending_date  \
# 0      0  2kyS6SvSYSE      17.14.11
# 1      1  1ZAPwfrtAFY      17.14.11
# 2      2  5qpjK5DgCt4      17.14.11
# 3      3  puqaWrEC7tY      17.14.11
# 4      4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id publish_date      time_frame published_day_of_week  \
# 0           22   13/11/2017  17:00 to 17:59                Monday
# 1           24   13/11/2017    7:00 to 7:59                Monday
# 2           23   12/11/2017  19:00 to 19:59                Sunday
# 3           24   13/11/2017  11:00 to 11:59                Monday
# 4           24   12/11/2017  18:00 to 18:59                Sunday
#
#   publish_country                                               tags    views  \
# 0              US                                    SHANtell martin   748374
# 1              US  last week tonight trump presidency|"last week ...  2418783
# 2              US  racist superman|"rudy""|""mancuso""|""king""|"...  3191434
# 3              US  rhett and link|"gmm""|""good mythical morning"...   343168
# 4              US  ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731
#
#     likes  dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0   57527      2966          15954              False             False
# 1   97185      6146          12703              False             False
# 2  146033      5339           8181              False             False
# 3   10172       666           2146              False             False
# 4  132235      1989          17518              False             False
#
#    video_error_or_removed
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %%
Youtube_df.tail()
# Out:
#          index     video_id trending_date  \
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags   views  likes  \
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...   80685   1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...  103339    460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...  773347  25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...  115225   2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...  107392    300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False

# %% [markdown]
# # CHECKING NULL VALUES AND DATA TYPES

# %%
Youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161470 entries, 0 to 161469
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   index                   161470 non-null  int64
#  1   video_id                161470 non-null  object
#  2   trending_date           161470 non-null  object
#  3   title                   161470 non-null  object
#  4   channel_title           161470 non-null  object
#  5   category_id             161470 non-null  int64
#  6   publish_date            161470 non-null  object
#  7   time_frame              161470 non-null  object
#  8   published_day_of_week   161470 non-null  object
#  9   publish_country         161470 non-null  object
#  10  tags                    161470 non-null  object
#  11  views                   161470 non-null  int64
#  12  likes                   161470 non-null  int64
#  13  dislikes                161470 non-null  int64
#  14  comment_count           161470 non-null  int64
#  15  comments_disabled       161470 non-null  bool
#  16  ratings_disabled        161470 non-null  bool
#  17  video_error_or_removed  161470 non-null  bool
# dtypes: bool(3), int64(6), object(9)
# memory usage: 18.9+ MB

# %%
Youtube_df.describe()
# Out:
#               index    category_id         views         likes      dislikes  \
# count  161470.00000  161470.000000  1.614700e+05  1.614700e+05  1.614700e+05
# mean    80734.50000      19.461151  2.419854e+06  6.566194e+04  3.490153e+03
# std     46612.51832       7.432001  1.043749e+07  2.260617e+05  3.114779e+04
# min         0.00000       1.000000  2.230000e+02  0.000000e+00  0.000000e+00
# 25%     40367.25000      15.000000  1.015382e+05  1.975000e+03  8.500000e+01
# 50%     80734.50000      23.000000  3.847395e+05  9.840000e+03  3.480000e+02
# 75%    121101.75000      24.000000  1.339528e+06  4.006275e+04  1.350000e+03
# max    161469.00000      44.000000  4.245389e+08  5.613827e+06  1.944971e+06
#
#        comment_count
# count   1.614700e+05
# mean    7.035494e+03
# std     3.404121e+04
# min     0.000000e+00
# 25%     2.790000e+02
# 50%     1.144000e+03
# 75%     4.144750e+03
# max     1.626501e+06

# %% [markdown]
# # REMOVING UNWANTED COLUMNS

# %%
del_cols = ['comments_disabled','ratings_disabled', 'video_error_or_removed' , 'time_frame',]
Youtube_df = Youtube_df.drop(del_cols, axis=1)

# %%
Youtube_df
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date  \
# 0                   CaseyNeistat           22   13/11/2017
# 1                LastWeekTonight           24   13/11/2017
# 2                   Rudy Mancuso           23   12/11/2017
# 3          Good Mythical Morning           24   13/11/2017
# 4                       nigahiga           24   12/11/2017
# ...                          ...          ...          ...
# 161465           Annoying Orange           24   13/06/2018
# 161466          Elhiwar Ettounsi           24   13/06/2018
# 161467            Kingdom Hearts           20   11/06/2018
# 161468           The Young Turks           25   13/06/2018
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count
# 0           2966          15954
# 1           6146          12703
# 2           5339           8181
# 3            666           2146
# 4           1989          17518
# ...          ...            ...
# 161465        99           1312
# 161466        66             51
# 161467       224           3881
# 161468       182           1672
# 161469        62            251
#
# [161470 rows x 14 columns]

# %% [markdown]
# # CHECKING IF THERE ANY DUPLICTAE VALUES PRESENT IN THE CURRENT DATASET

# %%
Youtube_df['duplicated'] = Youtube_df.duplicated()
result = Youtube_df['duplicated'].value_counts()
print(result)
# Out:
# False    161470
# Name: duplicated, dtype: int64

# %% [markdown]
# # CHANGING THE DATA TYPE IN THE CORRECT FORMAT FOR THE DATE DATA TYPE

# %%
Youtube_df['trending_date'] = pd.to_datetime(Youtube_df['trending_date'], format='%y.%d.%m')
Youtube_df['publish_date'] = pd.to_datetime(Youtube_df['publish_date'], format='%d/%m/%Y', errors='coerce')

# %%
Youtube_df
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE    2017-11-14
# 1            1  1ZAPwfrtAFY    2017-11-14
# 2            2  5qpjK5DgCt4    2017-11-14
# 3            3  puqaWrEC7tY    2017-11-14
# 4            4  d380meD0W0M    2017-11-14
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ    2018-06-14
# 161466  161466  8HNuRNi8t70    2018-06-14
# 161467  161467  GWlKEM3m2EE    2018-06-14
# 161468  161468  lbMKLzQ4cNQ    2018-06-14
# 161469  161469  POTgw38-m58    2018-06-14
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date  \
# 0                   CaseyNeistat           22   2017-11-13
# 1                LastWeekTonight           24   2017-11-13
# 2                   Rudy Mancuso           23   2017-11-12
# 3          Good Mythical Morning           24   2017-11-13
# 4                       nigahiga           24   2017-11-12
# ...                          ...          ...          ...
# 161465           Annoying Orange           24   2018-06-13
# 161466          Elhiwar Ettounsi           24   2018-06-13
# 161467            Kingdom Hearts           20   2018-06-11
# 161468           The Young Turks           25   2018-06-13
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   2018-06-13
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  duplicated
# 0           2966          15954       False
# 1           6146          12703       False
# 2           5339           8181       False
# 3            666           2146       False
# 4           1989          17518       False
# ...          ...            ...         ...
# 161465        99           1312       False
# 161466        66             51       False
# 161467       224           3881       False
# 161468       182           1672       False
# 161469        62            251       False
#
# [161470 rows x 15 columns]

# %%
Youtube_df = Youtube_df.drop("duplicated", axis=1)
Youtube_df
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE    2017-11-14
# 1            1  1ZAPwfrtAFY    2017-11-14
# 2            2  5qpjK5DgCt4    2017-11-14
# 3            3  puqaWrEC7tY    2017-11-14
# 4            4  d380meD0W0M    2017-11-14
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ    2018-06-14
# 161466  161466  8HNuRNi8t70    2018-06-14
# 161467  161467  GWlKEM3m2EE    2018-06-14
# 161468  161468  lbMKLzQ4cNQ    2018-06-14
# 161469  161469  POTgw38-m58    2018-06-14
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date  \
# 0                   CaseyNeistat           22   2017-11-13
# 1                LastWeekTonight           24   2017-11-13
# 2                   Rudy Mancuso           23   2017-11-12
# 3          Good Mythical Morning           24   2017-11-13
# 4                       nigahiga           24   2017-11-12
# ...                          ...          ...          ...
# 161465           Annoying Orange           24   2018-06-13
# 161466          Elhiwar Ettounsi           24   2018-06-13
# 161467            Kingdom Hearts           20   2018-06-11
# 161468           The Young Turks           25   2018-06-13
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   2018-06-13
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count
# 0           2966          15954
# 1           6146          12703
# 2           5339           8181
# 3            666           2146
# 4           1989          17518
# ...          ...            ...
# 161465        99           1312
# 161466        66             51
# 161467       224           3881
# 161468       182           1672
# 161469        62            251
#
# [161470 rows x 14 columns]

# %% [markdown]
# # CREATING A FUNCTION FOR VIEWING TOP 5 AND LAST 5 VALUES

# %%
def print_top5(column_of_interest,column_stats):
    df = Youtube_df.groupby(column_of_interest)['views', 'likes','comment_count', 'dislikes'].apply(lambda x: x.astype(int).sum())
    return df.sort_values(by=column_stats, ascending=False).head()

# %%
def print_last5(column_of_interest,column_stats):
    df = Youtube_df.groupby(column_of_interest)['views', 'likes','comment_count', 'dislikes'].apply(lambda x: x.astype(int).sum())
    return df.sort_values(by=column_stats, ascending=True).head()

# %% [markdown]
# ## Top 5 Videos with Highest Views

# %%
print_top5('title','views')
# Out:
#                                                           views      likes  \
# title
# Childish Gambino - This Is America (Official Vi...  10425338513  265935343
# Nicky Jam x J. Balvin - X (EQUIS) | Video Ofici...   8395094350   62438438
# Bad Bunny - Amorfoda | Video Oficial                 6970018019  111253872
# Ariana Grande - No Tears Left To Cry                 5872980845  162132923
# Te Bote Remix - Casper, Nio GarcÃ­a, Darell, Ni...   5168434018   54135423
#
#                                                     comment_count  dislikes
# title
# Childish Gambino - This Is America (Official Vi...       27796551  16564194
# Nicky Jam x J. Balvin - X (EQUIS) | Video Ofici...        2316279   2973389
# Bad Bunny - Amorfoda | Video Oficial                      6439286   5398588
# Ariana Grande - No Tears Left To Cry                     13498459   6306520
# Te Bote Remix - Casper, Nio GarcÃ­a, Darell, Ni...        2025882   2819055

# %% [markdown]
# # Videos With Lowest Views

# %%
print_last5('title','views')
# Out:
#                                                     views  likes  \
# title
# France: Famous climber Alain Rober scales skysc...    284      3
# L'histoire des enfants Tinning | La mÃ¨re aux n...    365     43
# FeÌvrier 2018, Performance 8 10 Ans                  374     43
# La chanson de nos 14 ans (15/02/2018) - Best Of...    385     40
# 2/2 â© Coffret de communication : Les RJ45 STP...    404     47
#
#                                                     comment_count  dislikes
# title
# France: Famous climber Alain Rober scales skysc...              0         0
# L'histoire des enfants Tinning | La mÃ¨re aux n...             14         2
# FeÌvrier 2018, Performance 8 10 Ans                            5         0
# La chanson de nos 14 ans (15/02/2018) - Best Of...              3         0
# 2/2 â© Coffret de communication : Les RJ45 STP...              5         2

# %% [markdown]
# # Top 5 Videos with Highest likes

# %%
print_top5('title','likes')
# Out:
#                                                           views      likes  \
# title
# Childish Gambino - This Is America (Official Vi...  10425338513  265935343
# BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV        3055662678  179849973
# Ariana Grande - No Tears Left To Cry                 5872980845  162132923
# Drake - Godâ€™s Plan                                 4895081566  136390285
# Bad Bunny - Amorfoda | Video Oficial                 6970018019  111253872
#
#                                                     comment_count  dislikes
# title
# Childish Gambino - This Is America (Official Vi...       27796551  16564194
# BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV            38614637   5768877
# Ariana Grande - No Tears Left To Cry                     13498459   6306520
# Drake - Godâ€™s Plan                                      8772422   2560165
# Bad Bunny - Amorfoda | Video Oficial                      6439286   5398588

# %% [markdown]
# # Videos With Lowest Likes

# %%
print_last5('title','likes')
# Out:
#                                                       views  likes  \
# title
# ðŸ•Œ  Ramadan 2018 | Msemen Farcis bechahma Un ...    59400      0
# A Hidden Warning from History!                        42746      0
# à®šà®±à¯à®±à¯ à®®à¯à®©à¯ à®šà®šà®¿à®•à®²à®¾...   907048      0
# Le rorqual Ã©chouÃ© en Gironde dissÃ©quÃ© par l...     3080      0
# I Like Beer (:60) | Michelob ULTRA Super Bowl       2868544      0
#
#                                                     comment_count  dislikes
# title
# ðŸ•Œ  Ramadan 2018 | Msemen Farcis bechahma Un ...            314         0
# A Hidden Warning from History!                               1053         0
# à®šà®±à¯à®±à¯ à®®à¯à®©à¯ à®šà®šà®¿à®•à®²à®¾...            182         0
# Le rorqual Ã©chouÃ© en Gironde dissÃ©quÃ© par l...              0         1
# I Like Beer (:60) | Michelob ULTRA Super Bowl                  60         0

# %% [markdown]
# # Top 5 Videos with Highest Dislikes

# %%
print_top5('title','dislikes')
# Out:
#                                                           views      likes  \
# title
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind   4070143496   96438271
# So Sorry.                                             712094226   27689216
# Childish Gambino - This Is America (Official Vi...  10425338513  265935343
# Suicide: Be Here Tomorrow.                            547739263   49620129
# Lucas Lucco e Pabllo Vittar - ParaÃ­so               1073294377   28344732
#
#                                                     comment_count  dislikes
# title
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind       27876748  49680581
# So Sorry.                                                27271712  31575810
# Childish Gambino - This Is America (Official Vi...       27796551  16564194
# Suicide: Be Here Tomorrow.                               16476651  11246153
# Lucas Lucco e Pabllo Vittar - ParaÃ­so                    6861819  10006058

# %% [markdown]
# # Videos With Lowest DisLikes

# %%
print_last5('title','dislikes')
# Out:
#                                                     views  likes  \
# title
# ðŸ•Œ  Ramadan 2018 | Msemen Farcis bechahma Un ...  59400      0
# un crash en voiture Ã  NÃ¼rburgring,                 4230      3
# Christmas Day 2000                                  24546     19
# PlanÃ¨te Rap - RomÃ©o Elvis Morale2Luxe #Jeudi       2274     74
# Pity x 3.S1 x SÃ©rie Sims 4                          1910      0
#
#                                                     comment_count  dislikes
# title
# ðŸ•Œ  Ramadan 2018 | Msemen Farcis bechahma Un ...            314         0
# un crash en voiture Ã  NÃ¼rburgring,                            0         0
# Christmas Day 2000                                              1         0
# PlanÃ¨te Rap - RomÃ©o Elvis Morale2Luxe #Jeudi                 38         0
# Pity x 3.S1 x SÃ©rie Sims 4                                    57         0

# %% [markdown]
# # Top 5 Channels with Highest likes

# %%
print_top5('channel_title', 'views')
# Out:
#                             views      likes  comment_count  dislikes
# channel_title
# ChildishGambinoVEVO   10425338513  265935343       27796551  16564194
# NickyJamTV             9118588957   77527596        4234962   4951650
# Ozuna                  8465233685   76620691        3263914   4966543
# DrakeVEVO              7434941039  178049699       11146185   3975055
# Marvel Entertainment   7037198870  197199206       22986630   4020864

# %% [markdown]
# # Channels With Lowest likes

# %%
print_last5('channel_title', 'views')
# Out:
#                           views  likes  comment_count  dislikes
# channel_title
# No Comment TV               284      3              0         0
# NavylittleMonster           365     43             14         2
# Melimelo78                  374     43              5         0
# Pix'Perience                528     67              1         0
# Natsu et Lucy Heartfilia    543     56             13         0

# %% [markdown]
# # Correlation Matrix for Identifying Relationships

# %%
columns_of_interest = ['views', 'likes', 'dislikes','comment_count']
correlation_matrix = Youtube_df[columns_of_interest].corr()
correlation_matrix
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.786897  0.414189       0.499026
# likes          0.786897  1.000000  0.453304       0.776422
# dislikes       0.414189  0.453304  1.000000       0.732969
# comment_count  0.499026  0.776422  0.732969       1.000000

# %% [markdown]
# # Visualizing Correlation Matrix With Help Of Heatmap

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.4)
plt.title('Correlation Matrix Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# # Channels With The Highest Number Of Videos

# %%
Youtube_df['channel_title'].value_counts().head()
# Out:
# The Late Show with Stephen Colbert        653
# Late Night with Seth Meyers               594
# TheEllenShow                              586
# The Tonight Show Starring Jimmy Fallon    569
# Jimmy Kimmel Live                         560
# Name: channel_title, dtype: int64

# %% [markdown]
# # Channels With The Lowest Number Of Videos

# %%
Youtube_df['channel_title'].value_counts().tail()
# Out:
# RapLyricsVEVO        1
# Mazen Zbatata        1
# Karismatik Dancer    1
# Lucile Joseph        1
# SevenSuperGirls      1
# Name: channel_title, dtype: int64

# %% [markdown]
# # Countries With Highest Number Of Views

# %%
print_top5('publish_country','views')
# Out:
#                         views       likes  comment_count   dislikes
# publish_country
# GB               230069198174  5234962944      509346351  296250384
# US                96671770152  3041147198      345888164  151978155
# CANADA            46891975069  1618179878      206161849   82137919
# FRANCE            17100897444   708144090       74624804   33188528

# %% [markdown]
# # Extracting The Modified Dataset

# %%
Youtube_df.to_csv('youtube2.csv')

# %% [markdown]
# # Visualizing The Count of Videos Country-wise

# %%
plt.figure(figsize=(14, 10))
g = sns.countplot(x="publish_country", data=Youtube_df, palette="Reds", order=Youtube_df["publish_country"].value_counts().index)
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
g.set_title("Count of the Video - Country wise", fontsize=15)
g.set_xlabel(" Country", fontsize=12)
g.set_ylabel("Count", fontsize=12)
plt.subplots_adjust(wspace=0.9, hspace=0.9, top=0.9)
plt.show()

# %% [markdown]
# # Number of Videos Published in a Week

# %%
plt.figure(figsize=(14, 10))
g = sns.countplot(x="published_day_of_week", data=Youtube_df, palette="Reds", order=Youtube_df["published_day_of_week"].value_counts().index)
g.set_xticklabels(g.get_xticklabels(), rotation=45, ha="right")
g.set_title("Number of Videos Published in a Week", fontsize=15)
g.set_xlabel("Country", fontsize=12)
g.set_ylabel("Number Of Videos", fontsize=12)
plt.subplots_adjust(wspace=0.9, hspace=0.9, top=0.9)
plt.show()

# %% [markdown]
# # Pair Plot of views,likes,comment count and dislikes with respect to published week

# %%
data2_cols = Youtube_df[['views', 'likes', 'comment_count', 'dislikes', 'published_day_of_week']]
data2_cols['published_day_of_week'] = data2_cols['published_day_of_week'].astype('category')
data2_cols.dropna(subset=['published_day_of_week'], inplace=True)
sns.pairplot(data2_cols, hue='published_day_of_week', palette='coolwarm')
plt.show()

# %% [markdown]
# # Identifyng the Most Used Tags with help of Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS
plt.figure(figsize=(20, 20))

stopwords = set(STOPWORDS)
colormap = 'YlOrRd'

wordcloud = WordCloud(
    background_color='black',
    stopwords=stopwords,
    max_words=100,
    max_font_size=120,
    random_state=0,
    colormap=colormap
).generate(str(Youtube_df['tags']))

plt.imshow(wordcloud)
plt.title('WORD CLOUD for Tags', fontsize=20)
plt.axis('off')
plt.show()
